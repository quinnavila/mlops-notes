# %%
# !python -V
# Out:
# Python 3.11.1

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
# needed to read parqyet files
# %pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N  \
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
df.describe()
# Out:
#            VendorID           lpep_pickup_datetime
# count  76518.000000                          76518  \
# mean       1.905290  2021-01-16 15:52:22.173017856
# min        1.000000            2009-01-01 00:03:25
# 25%        2.000000            2021-01-08 23:22:00
# 50%        2.000000            2021-01-16 10:11:45
# 75%        2.000000  2021-01-24 09:41:04.249999872
# max        2.000000            2021-01-31 23:46:45
# std        0.292816                            NaN
#
#                lpep_dropoff_datetime    RatecodeID  PULocationID
# count                          76518  40471.000000  76518.000000  \
# mean   2021-01-16 16:12:17.846781440      1.143041    109.590371
# min              2009-01-01 00:12:25      1.000000      1.000000
# 25%              2021-01-08 23:42:32      1.000000     55.000000
# 50%       2021-01-16 10:30:42.500000      1.000000     76.000000
# 75%              2021-01-24 09:55:45      1.000000    166.000000
# ...

# %%
# create duration
df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
# convert to minutes for our study
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
df.duration.describe()
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 25%          8.000000
# 50%         13.883333
# 75%         23.000000
# max       1439.600000
# Name: duration, dtype: float64

# %%
df.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 50%         13.883333
# 95%         44.000000
# 98%         56.000000
# 99%         67.158167
# max       1439.600000
# Name: duration, dtype: float64

# %%
((df.duration >=1) & (df.duration <= 60)).mean()
# Out:
# 0.9658903787344154

# %%
# note distplot is deprecated using displot
# note the long tail.
sns.displot(df.duration)

# %%
df = df[(df.duration >= 1) & (df.duration <= 60)]
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N  \
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7             2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']
df[categorical].dtypes
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %%
# for OHE we are converting to a string using dictvectorizer
df[categorical] = df[categorical].astype(str)
# Out:
# /var/folders/c8/mb9hkcmn25ndndk26w6xnvh80000gn/T/ipykernel_50688/2210850733.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
df[categorical].dtypes
# Out:
# PULocationID    object
# DOLocationID    object
# dtype: object

# %%
df.DOLocationID.isnull().sum()
# Out:
# 0

# %%
df[categorical + numerical].iloc[:10]
# Out:
#    PULocationID DOLocationID  trip_distance
# 0            43          151           1.01
# 1           166          239           2.53
# 2            41           42           1.12
# 3           168           75           1.99
# 7            75           75           0.45
# 9           225          265          12.19
# 10          244          244           3.39
# 11           75          213           6.69
# 12           74          238           2.34
# 13           74           60           5.48

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')
train_dicts[:10]
# Out:
# [{'PULocationID': '43', 'DOLocationID': '151', 'trip_distance': 1.01},
#  {'PULocationID': '166', 'DOLocationID': '239', 'trip_distance': 2.53},
#  {'PULocationID': '41', 'DOLocationID': '42', 'trip_distance': 1.12},
#  {'PULocationID': '168', 'DOLocationID': '75', 'trip_distance': 1.99},
#  {'PULocationID': '75', 'DOLocationID': '75', 'trip_distance': 0.45},
#  {'PULocationID': '225', 'DOLocationID': '265', 'trip_distance': 12.19},
#  {'PULocationID': '244', 'DOLocationID': '244', 'trip_distance': 3.39},
#  {'PULocationID': '75', 'DOLocationID': '213', 'trip_distance': 6.69},
#  {'PULocationID': '74', 'DOLocationID': '238', 'trip_distance': 2.34},
#  {'PULocationID': '74', 'DOLocationID': '60', 'trip_distance': 5.48}]

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)
# X_train
names = dv.get_feature_names_out()

# %%
print(X_train.toarray())

# %%
len(names)
# Out:
# 507

# %%
print(len(dv.feature_names_))
# Out:
# 507

# %%
target = 'duration'
y_train = df[target].values

# %%
y_train
# Out:
# array([ 3.93333333,  8.75      ,  5.96666667, ..., 11.        ,
#        27.        , 10.        ])

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 9.838799799886667

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /var/folders/c8/mb9hkcmn25ndndk26w6xnvh80000gn/T/ipykernel_39414/1672306066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /var/folders/c8/mb9hkcmn25ndndk26w6xnvh80000gn/T/ipykernel_39414/1672306066.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715199477344

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
# testing Lasso LR with regularization
lr = Lasso(0.01)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 11.167275941179728

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# linear_reg = LinearRegression()
# decision_tree_reg = DecisionTreeRegressor()
# svr = SVR() # not this one
# mlp_reg = MLPRegressor()
# gradient_boost_reg = GradientBoostingRegressor()
# knn_reg = KNeighborsRegressor()

# linear_reg.fit(X_train, y_train)
# decision_tree_reg.fit(X_train, y_train)
# svr.fit(X_train, y_train)
# mlp_reg.fit(X_train, y_train)
# gradient_boost_reg.fit(X_train, y_train)
# knn_reg.fit(X_train, y_train)

# Step 4: Evaluate Model Performance
# linear_reg_pred = linear_reg.predict(X_val)
# decision_tree_pred = decision_tree_reg.predict(X_val)
# svr_pred = svr.predict(X_val)
# mlp_pred = mlp_reg.predict(X_val)
# gradient_boost_pred = gradient_boost_reg.predict(X_val)
# knn_pred = knn_reg.predict(X_val)

# Calculate evaluation metrics
# linear_reg_mse = mean_squared_error(y_val, linear_reg_pred, squared=False)
# decision_tree_mse = mean_squared_error(y_val, decision_tree_pred, squared=False)
# svr_mse = mean_squared_error(y_val, svr_pred, squared=False)
# mlp_mse = mean_squared_error(y_val, mlp_pred)
# gradient_boost_mse = mean_squared_error(y_val, gradient_boost_pred, squared=False)
# knn_mse = mean_squared_error(y_val, knn_pred, squared=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 10
#       3 svr = SVR()
#       4 # mlp_reg = MLPRegressor()
#       5 # gradient_boost_reg = GradientBoostingRegressor()
#       6 # knn_reg = KNeighborsRegressor()
#       7
#       8 # linear_reg.fit(X_train, y_train)
#       9 # decision_tree_reg.fit(X_train, y_train)
# ---> 10 svr.fit(X_train, y_train)
#      11 # mlp_reg.fit(X_train, y_train)
#      12 # gradient_boost_reg.fit(X_train, y_train)
#      13 # knn_reg.fit(X_train, y_train)
#    (...)
#      16 # linear_reg_pred = linear_reg.predict(X_val)
#      17 # decision_tree_pred = decision_tree_reg.predict(X_val)
#      18 svr_pred = svr.predict(X_val)
#
# File ~/.pyenv/versions/3.11.1/envs/practice2/lib/python3.11/site-packages/sklearn/svm/_base.py:252, in BaseLibSVM.fit(self, X, y, sample_weight)
#     249     print("[LibSVM]", end="")
# ...

# %%
# print(f"linear_reg {linear_reg_mse}")
# print(f"decision tree {decision_tree_mse}")
# print(f"svr_mse {svr_mse}")
# print(f"mlp_mse {mlp_mse}")
# print(f"gradient_boost_mse {gradient_boost_mse}")
# print(f"knn_mse {knn_mse}")
# Out:
# knn_mse 6.636142674440029

# %% [markdown]
# knn 6.63

# %%
from sklearn.model_selection import GridSearchCV

# Define the hyperparameters grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.1, 0.01],
    'max_depth': [3, 5, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}

# Create the GradientBoostingRegressor
gradient_boost_reg = GradientBoostingRegressor()

# Perform grid search
grid_search = GridSearchCV(gradient_boost_reg, param_grid, cv=3)
grid_search.fit(X_train, y_train)

# Get the best estimator (model) with the best hyperparameters
best_gradient_boost_reg = grid_search.best_estimator_

# Make predictions on the validation set using the best model
gradient_boost_pred = best_gradient_boost_reg.predict(X_val)

# Calculate evaluation metrics
gradient_boost_mse = mean_squared_error(y_val, gradient_boost_pred, squared=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 17
#      15 # Perform grid search
#      16 grid_search = GridSearchCV(gradient_boost_reg, param_grid, cv=5)
# ---> 17 grid_search.fit(X_train, y_train)
#      19 # Get the best estimator (model) with the best hyperparameters
#      20 best_gradient_boost_reg = grid_search.best_estimator_
#
# File ~/.pyenv/versions/3.11.1/envs/practice2/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
# ...

# %%
import xgboost as xgb
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# Step 3: Define the Parameters
params = {
    "learning_rate": 0.1,
    "max_depth": 5,
    "min_child_weight": 1,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "objective": "reg:squarederror",
    "seed": 42,
}

# Step 4: Train the Model
model = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=100,
    evals=[(valid, "validation")],
    early_stopping_rounds=10,
)

# Step 5: Make Predictions
y_pred = model.predict(valid)

# Step 6: Evaluate the Model
rmse = mean_squared_error(y_val, y_pred, squared=False)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# [0]	validation-rmse:19.42510
# [1]	validation-rmse:18.23007
# [2]	validation-rmse:16.78772
# [3]	validation-rmse:15.86510
# [4]	validation-rmse:14.69108
# [5]	validation-rmse:13.65356
# [6]	validation-rmse:12.73855
# [7]	validation-rmse:11.93598
# [8]	validation-rmse:11.23357
# [9]	validation-rmse:10.62042
# [10]	validation-rmse:10.08699
# [11]	validation-rmse:9.62450
# [12]	validation-rmse:9.22601
# [13]	validation-rmse:8.87877
# [14]	validation-rmse:8.57924
# [15]	validation-rmse:8.32247
# [16]	validation-rmse:8.09981
# [17]	validation-rmse:7.91021
# [18]	validation-rmse:7.74741
# [19]	validation-rmse:7.60939
# [20]	validation-rmse:7.52688
# [21]	validation-rmse:7.42107
# [22]	validation-rmse:7.32756
# [23]	validation-rmse:7.27500
# [24]	validation-rmse:7.20494
# [25]	validation-rmse:7.16590
# [26]	validation-rmse:7.10840
# [27]	validation-rmse:7.06004
# [28]	validation-rmse:7.01638
# [29]	validation-rmse:6.99357
# [30]	validation-rmse:6.97306
# [31]	validation-rmse:6.94060
# ...

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# Step 1: Convert data to DMatrix
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# Step 2: Define the hyperparameters grid
param_grid = {
    "learning_rate": [0.1, 0.01],
    "max_depth": [3, 5, 7],
    "min_child_weight": [1, 3],
    "subsample": [0.8, 0.9],
    "colsample_bytree": [0.8, 0.9],
}

# Step 3: Create the XGBoost regressor
xgb_reg = xgb.XGBRegressor(objective="reg:squarederror", seed=42)

# Step 4: Perform grid search
grid_search = GridSearchCV(xgb_reg, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Step 5: Get the best estimator (model) with the best hyperparameters
best_xgb_reg = grid_search.best_estimator_

# Step 6: Make predictions on the validation set using the best model
y_pred = best_xgb_reg.predict(X_val)

# Step 7: Evaluate the model
rmse = mean_squared_error(y_val, y_pred, squared=False)
print("Root Mean Squared Error (RMSE):", rmse)

# %%
# import lightgbm as lgb

# train_data = lgb.Dataset(X_train, label=y_train)

# # Step 3: Define the Parameters
# params = {
#     "objective": "regression",
#     "learning_rate": 0.1,
#     "max_depth": 5,
#     "min_child_samples": 20,
#     "subsample": 0.8,
#     "colsample_bytree": 0.8,
#     "seed": 42
# }

# # Step 4: Train the Model
# model = lgb.train(
#     params=params,
#     train_set=train_data,
#     num_boost_round=100,
#     valid_sets=[train_data],
#     early_stopping_rounds=10
# )

# # Step 5: Make Predictions
# y_pred = model.predict(X_val)

# # Step 6: Evaluate the Model
# rmse = mean_squared_error(y_val, y_pred, squared=False)
# print("Root Mean Squared Error (RMSE):", rmse)

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim

# class RegressionModel(nn.Module):
#     def __init__(self, input_size):
#         super(RegressionModel, self).__init__()
#         self.fc1 = nn.Linear(input_size, 64)
#         self.fc2 = nn.Linear(64, 32)
#         self.fc3 = nn.Linear(32, 1)

#     def forward(self, x):
#         x = torch.relu(self.fc1(x))
#         x = torch.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x

# model = RegressionModel(X_train.shape[1])

# # Step 3: Define the Loss Function and Optimizer
# criterion = nn.MSELoss()
# optimizer = optim.Adam(model.parameters(), lr=0.01)

# # Step 4: Train the Model
# num_epochs = 100
# batch_size = 32
# train_dataset = torch.utils.data.TensorDataset(torch.tensor(X_train), torch.tensor(y_train))
# train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# for epoch in range(num_epochs):
#     for inputs, targets in train_loader:
#         optimizer.zero_grad()
#         outputs = model(inputs.float())
#         loss = criterion(outputs.squeeze(), targets.float())
#         loss.backward()
#         optimizer.step()

# # Step 5: Make Predictions
# with torch.no_grad():
#     y_pred = model(torch.tensor(X_val).float())

# # Step 6: Evaluate the Model
# rmse = mean_squared_error(y_val, y_pred.numpy(), squared=False)
# print("Root Mean Squared Error (RMSE):", rmse)

# %%
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense

# # Step 2: Define the Model
# model = Sequential()
# model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))

# # Step 3: Compile the Model
# model.compile(loss='mean_squared_error', optimizer='adam')

# # Step 4: Train the Model
# num_epochs = 100
# batch_size = 32

# model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size, verbose=1)

# # Step 5: Make Predictions
# y_pred = model.predict(X_val)

# # Step 6: Evaluate the Model
# rmse = mean_squared_error(y_val, y_pred, squared=False)
# print("Root Mean Squared Error (RMSE):", rmse)
